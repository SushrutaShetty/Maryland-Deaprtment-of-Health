# %% [markdown]
# <a href="https://colab.research.google.com/github/SushrutaShetty/Maryland-Deaprtment-of-Health/blob/main/Violent_Crime%26Property_Crime_Initial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

# %%
crime = pd.read_csv('/content/drive/MyDrive/Violent Crime & Property Crime Project/Violent_Crime___Property_Crime_Statewide_Totals__1975_to_Present.csv')

# %%
crime.shape
# Out:
# (46, 38)

# %% [markdown]
# **M/V theft** is motor vehicle theft.
#
# **B & E** is breaking and Entering.
#
# **LARCENY THEFT** is unlawful taking, carrying, leading, or riding away of property from the possession or constructive possession of another. Examples are thefts of bicycles, thefts of motor vehicle parts and accessories, shoplifting, pocket-picking, or the stealing of any property or article that is not taken by force and violence or by fraud.
#
# **AGG. ASSAULT** is  an attack on another person that's enhanced by other factors like the use of a weapon, serious injuries or an attack on a police officer
#
#
#
#
# ref: https://www.urbandictionary.com/define.php?term=MV%20Theft
# https://www.dictionary.com/browse/b-and-e#:~:text=Law.,of%20the%20crime%20of%20burglary.

# %%
crime.columns
# Out:
# Index(['JURISDICTION', 'YEAR', 'POPULATION', 'MURDER', 'RAPE', 'ROBBERY',
#        'AGG. ASSAULT', 'B & E', 'LARCENY THEFT', 'M/V THEFT', 'GRAND TOTAL',
#        'PERCENT CHANGE', 'VIOLENT CRIME TOTAL', 'VIOLENT CRIME PERCENT',
#        'VIOLENT CRIME PERCENT CHANGE', 'PROPERTY CRIME TOTALS',
#        'PROPERTY CRIME PERCENT', 'PROPERTY CRIME PERCENT CHANGE',
#        'OVERALL CRIME RATE PER 100,000 PEOPLE',
#        'OVERALL PERCENT CHANGE PER 100,000 PEOPLE',
#        'VIOLENT CRIME RATE PER 100,000 PEOPLE',
#        'VIOLENT CRIME RATE PERCENT CHANGE PER 100,000 PEOPLE',
#        'PROPERTY CRIME RATE PER 100,000 PEOPLE',
#        'PROPERTY CRIME RATE PERCENT CHANGE PER 100,000 PEOPLE',
#        'MURDER PER 100,000 PEOPLE', 'RAPE PER 100,000 PEOPLE',
#        'ROBBERY PER 100,000 PEOPLE', 'AGG. ASSAULT PER 100,000 PEOPLE',
#        'B & E PER 100,000 PEOPLE', 'LARCENY THEFT PER 100,000 PEOPLE',
#        'M/V THEFT PER 100,000 PEOPLE',
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 38 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   JURISDICTION                                           46 non-null     object
#  1   YEAR                                                   46 non-null     int64
#  2   POPULATION                                             46 non-null     int64
#  3   MURDER                                                 46 non-null     int64
#  4   RAPE                                                   46 non-null     int64
#  5   ROBBERY                                                46 non-null     int64
#  6   AGG. ASSAULT                                           46 non-null     int64
#  7   B & E                                                  46 non-null     int64
# ...

# %%
# crime['YEAR']= pd.to_datetime(crime['YEAR'])

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 38 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   JURISDICTION                                           46 non-null     object
#  1   YEAR                                                   46 non-null     int64
#  2   POPULATION                                             46 non-null     int64
#  3   MURDER                                                 46 non-null     int64
#  4   RAPE                                                   46 non-null     int64
#  5   ROBBERY                                                46 non-null     int64
#  6   AGG. ASSAULT                                           46 non-null     int64
#  7   B & E                                                  46 non-null     int64
# ...

# %%
pd.set_option('display.max_columns', None)
crime.head(10)
# Out:
#   JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 0     Maryland  1975     4098000     435  1288    14104         13251  57936
# 1     Maryland  1976     4144000     352  1327    12247         12322  56351
# 2     Maryland  1977     4139000     333  1439    12088         14856  57938
# 3     Maryland  1978     4143000     338  1476    12828         15686  58901
# 4     Maryland  1979     4149000     406  1628    13745         17337  62657
# 5     Maryland  1980     4192211     399  1681    16462         17182  71130
# 6     Maryland  1981     4261000     422  1663    18095         17691  70762
# 7     Maryland  1982     4265000     431  1596    15377         18845  60547
# 8     Maryland  1983     4304000     367  1412    14950         18007  52697
# 9     Maryland  1984     4349000     354  1644    13113         19369  51498
#
#    LARCENY THEFT  M/V THEFT  GRAND TOTAL  PERCENT CHANGE  VIOLENT CRIME TOTAL  \
# ...

# %%
crime.tail()
# Out:
#    JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 41     Maryland  2016     6016447     534  1815    10814         15828  24822
# 42     Maryland  2017     6052121     569  1773    11295         17049  23735
# 43     Maryland  2018     6042718     489  2106     9753         16294  18933
# 44     Maryland  2019     6045674     543  1979     9261         15985  16865
# 45     Maryland  2020     6055578     573  1891     7240         15260  14927
#
#     LARCENY THEFT  M/V THEFT  GRAND TOTAL  PERCENT CHANGE  \
# 41         100876      13847       168536            -2.1
# 42          99119      13553       167093            -0.9
# 43          92414      12146       152135            -9.0
# 44          89927      11255       145815            -4.2
# 45          72865      10683       123439           -15.3
#
#     VIOLENT CRIME TOTAL  VIOLENT CRIME PERCENT  VIOLENT CRIME PERCENT CHANGE  \
# ...

# %% [markdown]
# **Missing Values**

# %%
crime.describe()
# Out:
#               YEAR    POPULATION      MURDER         RAPE       ROBBERY  \
# count    46.000000  4.600000e+01   46.000000    46.000000     46.000000
# mean   1997.500000  5.125707e+06  476.195652  1616.630435  14029.043478
# std      13.422618  6.708911e+05   84.214177   340.643467   3418.800472
# min    1975.000000  4.098000e+06  333.000000  1127.000000   7240.000000
# 25%    1986.250000  4.481000e+06  400.750000  1318.750000  12027.250000
# 50%    1997.500000  5.114500e+06  490.500000  1636.000000  13628.500000
# 75%    2008.750000  5.683008e+06  550.750000  1872.000000  15358.500000
# max    2020.000000  6.055578e+06  632.000000  2280.000000  21580.000000
#
#        AGG. ASSAULT         B & E  LARCENY THEFT     M/V THEFT    GRAND TOTAL  \
# count     46.000000     46.000000      46.000000     46.000000      46.000000
# mean   20227.826087  44818.913043  133929.152174  24074.934783  239172.695652
# std     4052.913664  13698.069985   23174.984288   8770.183070   46711.392754
# ...

# %%
features_with_na=[features for features in crime.columns if crime[features].isnull().sum()>1]

for feature in features_with_na:
    print(feature, np.round(crime[feature].isnull().mean(), 4),  ' % missing values')

# %%
crime.isnull().sum() ##Column wise null/missing values
# Out:
# JURISDICTION                                             0
# YEAR                                                     0
# POPULATION                                               0
# MURDER                                                   0
# RAPE                                                     0
# ROBBERY                                                  0
# AGG. ASSAULT                                             0
# B & E                                                    0
# LARCENY THEFT                                            0
# M/V THEFT                                                0
# GRAND TOTAL                                              0
# PERCENT CHANGE                                           1
# VIOLENT CRIME TOTAL                                      0
# VIOLENT CRIME PERCENT                                    0
# VIOLENT CRIME PERCENT CHANGE                             1
# PROPERTY CRIME TOTALS                                    0
# ...

# %%
crime.isnull().sum().sum()
# Out:
# 13

# %% [markdown]
# **Outlier Detection and Removal**

# %%
crime.boxplot(column = 'GRAND TOTAL')
# Out:
# <Axes: >

# %%
import plotly.express as px
px.box(data_frame = crime, x = 'GRAND TOTAL')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(np.where(crime['GRAND TOTAL'] < 145000))
# Out:
# (array([45]),)

# %% [markdown]
# Drop year 2020.

# %%
##amke the eyar column as index and drop 2020 index
crime.set_index('YEAR')
# Out:
#      JURISDICTION  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# YEAR
# 1975     Maryland     4098000     435  1288    14104         13251  57936
# 1976     Maryland     4144000     352  1327    12247         12322  56351
# 1977     Maryland     4139000     333  1439    12088         14856  57938
# 1978     Maryland     4143000     338  1476    12828         15686  58901
# 1979     Maryland     4149000     406  1628    13745         17337  62657
# 1980     Maryland     4192211     399  1681    16462         17182  71130
# 1981     Maryland     4261000     422  1663    18095         17691  70762
# 1982     Maryland     4265000     431  1596    15377         18845  60547
# 1983     Maryland     4304000     367  1412    14950         18007  52697
# 1984     Maryland     4349000     354  1644    13113         19369  51498
# 1985     Maryland     4392000     350  1711    13276         21425  53168
# 1986     Maryland     4463000     398  1947    13570         21226  55596
# ...

# %%
crime_df = crime.drop(crime.index[[0, 45]], axis= 0)
crime_df.tail()
# Out:
#    JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 40     Maryland  2015     6006401     553  1758    10150         15850  26741
# 41     Maryland  2016     6016447     534  1815    10814         15828  24822
# 42     Maryland  2017     6052121     569  1773    11295         17049  23735
# 43     Maryland  2018     6042718     489  2106     9753         16294  18933
# 44     Maryland  2019     6045674     543  1979     9261         15985  16865
#
#     LARCENY THEFT  M/V THEFT  GRAND TOTAL  PERCENT CHANGE  \
# 40         103566      13564       172182            -2.7
# 41         100876      13847       168536            -2.1
# 42          99119      13553       167093            -0.9
# 43          92414      12146       152135            -9.0
# 44          89927      11255       145815            -4.2
#
#     VIOLENT CRIME TOTAL  VIOLENT CRIME PERCENT  VIOLENT CRIME PERCENT CHANGE  \
# ...

# %%
crime_df.drop(['JURISDICTION'], axis = 1, inplace = True)

# %%
crime_df
# Out:
#     YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 1   1976     4144000     352  1327    12247         12322  56351
# 2   1977     4139000     333  1439    12088         14856  57938
# 3   1978     4143000     338  1476    12828         15686  58901
# 4   1979     4149000     406  1628    13745         17337  62657
# 5   1980     4192211     399  1681    16462         17182  71130
# 6   1981     4261000     422  1663    18095         17691  70762
# 7   1982     4265000     431  1596    15377         18845  60547
# 8   1983     4304000     367  1412    14950         18007  52697
# 9   1984     4349000     354  1644    13113         19369  51498
# 10  1985     4392000     350  1711    13276         21425  53168
# 11  1986     4463000     398  1947    13570         21226  55596
# 12  1987     4535000     444  1894    13363         19597  53226
# 13  1988     4644000     452  1721    13991         21290  54696
# ...

# %% [markdown]
# Features of Intrest:
#
# YEAR
# POPULATION
# MURDER
# RAPE
# ROBBERY
# AGG. ASSAULT
# B & E
# LARCENY THEFT
# M/V THEFT

# %% [markdown]
# Overall crime rate is the total crime reported in that year to the total population.
#
# We divide the **OVERALL CRIME RATE PER 100,000 PEOPLE**  by 100,000 to see the change in crime rate over the years.

# %%
crime_df.set_index('YEAR')
# Out:
#       POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  LARCENY THEFT  \
# YEAR
# 1976     4144000     352  1327    12247         12322  56351         134337
# 1977     4139000     333  1439    12088         14856  57938         131516
# 1978     4143000     338  1476    12828         15686  58901         134012
# 1979     4149000     406  1628    13745         17337  62657         145278
# 1980     4192211     399  1681    16462         17182  71130         152089
# 1981     4261000     422  1663    18095         17691  70762         152544
# 1982     4265000     431  1596    15377         18845  60547         142903
# 1983     4304000     367  1412    14950         18007  52697         127443
# 1984     4349000     354  1644    13113         19369  51498         123625
# 1985     4392000     350  1711    13276         21425  53168         126193
# 1986     4463000     398  1947    13570         21226  55596         132899
# ...

# %%
crime_df.columns
# Out:
# Index(['YEAR', 'POPULATION', 'MURDER', 'RAPE', 'ROBBERY', 'AGG. ASSAULT',
#        'B & E', 'LARCENY THEFT', 'M/V THEFT', 'GRAND TOTAL', 'PERCENT CHANGE',
#        'VIOLENT CRIME TOTAL', 'VIOLENT CRIME PERCENT',
#        'VIOLENT CRIME PERCENT CHANGE', 'PROPERTY CRIME TOTALS',
#        'PROPERTY CRIME PERCENT', 'PROPERTY CRIME PERCENT CHANGE',
#        'OVERALL CRIME RATE PER 100,000 PEOPLE',
#        'OVERALL PERCENT CHANGE PER 100,000 PEOPLE',
#        'VIOLENT CRIME RATE PER 100,000 PEOPLE',
#        'VIOLENT CRIME RATE PERCENT CHANGE PER 100,000 PEOPLE',
#        'PROPERTY CRIME RATE PER 100,000 PEOPLE',
#        'PROPERTY CRIME RATE PERCENT CHANGE PER 100,000 PEOPLE',
#        'MURDER PER 100,000 PEOPLE', 'RAPE PER 100,000 PEOPLE',
#        'ROBBERY PER 100,000 PEOPLE', 'AGG. ASSAULT PER 100,000 PEOPLE',
#        'B & E PER 100,000 PEOPLE', 'LARCENY THEFT PER 100,000 PEOPLE',
#        'M/V THEFT PER 100,000 PEOPLE',
#        'MURDER  RATE PERCENT CHANGE PER 100,000 PEOPLE',
# ...

# %%
crime_df.set_axis(['YEAR', 'POPULATION', 'MURDER', 'RAPE', 'ROBBERY', 'AGG. ASSAULT',
       'B & E', 'LARCENY THEFT', 'M/V THEFT', 'GRAND TOTAL', 'PERCENT CHANGE',
       'VIOLENT CRIME TOTAL', 'VIOLENT CRIME PERCENT',
       'VIOLENT CRIME PERCENT CHANGE', 'PROPERTY CRIME TOTALS',
       'PROPERTY CRIME PERCENT', 'PROPERTY CRIME PERCENT CHANGE',
       'OVERALL CRIME RATE PER 100K PEOPLE',
       'OVERALL PERCENT CHANGE PER 100K PEOPLE',
       'VIOLENT CRIME RATE PER 100K PEOPLE',
       'VIOLENT CRIME RATE PERCENT CHANGE PER 100K PEOPLE',
       'PROPERTY CRIME RATE PER 100K PEOPLE',
       'PROPERTY CRIME RATE PERCENT CHANGE PER 100K PEOPLE',
       'MURDER PER 100K PEOPLE', 'RAPE PER 100K PEOPLE',
       'ROBBERY PER 100K PEOPLE', 'AGG. ASSAULT PER 100K PEOPLE',
       'B & E PER 100K PEOPLE', 'LARCENY THEFT PER 100K PEOPLE',
       'M/V THEFT PER 100K PEOPLE',
       'MURDER  RATE PERCENT CHANGE PER 100K PEOPLE',
       'RAPE RATE PERCENT CHANGE PER 100K PEOPLE',
       'ROBBERY RATE PERCENT CHANGE PER 100K PEOPLE',
       'AGG. ASSAULT  RATE PERCENT CHANGE PER 100K PEOPLE',
       'B & E RATE PERCENT CHANGE PER 100K PEOPLE',
       'LARCENY THEFT  RATE PERCENT CHANGE PER 100K PEOPLE',
       'M/V THEFT  RATE PERCENT CHANGE PER 100K PEOPLE'], axis='columns', inplace = True)

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 1 to 44
# Data columns (total 37 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   YEAR                                                44 non-null     int64
#  1   POPULATION                                          44 non-null     int64
#  2   MURDER                                              44 non-null     int64
#  3   RAPE                                                44 non-null     int64
#  4   ROBBERY                                             44 non-null     int64
#  5   AGG. ASSAULT                                        44 non-null     int64
#  6   B & E                                               44 non-null     int64
#  7   LARCENY THEFT                                       44 non-null     int64
#  8   M/V THEFT                                           44 non-null     int64
# ...

# %%
pd.to_datetime(crime_df['YEAR'], format = '%Y')
# Out:
# 1    1976-01-01
# 2    1977-01-01
# 3    1978-01-01
# 4    1979-01-01
# 5    1980-01-01
# 6    1981-01-01
# 7    1982-01-01
# 8    1983-01-01
# 9    1984-01-01
# 10   1985-01-01
# 11   1986-01-01
# 12   1987-01-01
# 13   1988-01-01
# 14   1989-01-01
# 15   1990-01-01
# 16   1991-01-01
# 17   1992-01-01
# 18   1993-01-01
# 19   1994-01-01
# 20   1995-01-01
# 21   1996-01-01
# 22   1997-01-01
# 23   1998-01-01
# 24   1999-01-01
# 25   2000-01-01
# 26   2001-01-01
# 27   2002-01-01
# 28   2003-01-01
# 29   2004-01-01
# 30   2005-01-01
# 31   2006-01-01
# 32   2007-01-01
# 33   2008-01-01
# 34   2009-01-01
# 35   2010-01-01
# 36   2011-01-01
# 37   2012-01-01
# 38   2013-01-01
# 39   2014-01-01
# 40   2015-01-01
# 41   2016-01-01
# 42   2017-01-01
# 43   2018-01-01
# 44   2019-01-01
# Name: YEAR, dtype: datetime64[ns]

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 1 to 44
# Data columns (total 37 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   YEAR                                                44 non-null     int64
#  1   POPULATION                                          44 non-null     int64
#  2   MURDER                                              44 non-null     int64
#  3   RAPE                                                44 non-null     int64
#  4   ROBBERY                                             44 non-null     int64
#  5   AGG. ASSAULT                                        44 non-null     int64
#  6   B & E                                               44 non-null     int64
#  7   LARCENY THEFT                                       44 non-null     int64
#  8   M/V THEFT                                           44 non-null     int64
# ...

# %%
crime_df.head()
# Out:
#    YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 1  1976     4144000     352  1327    12247         12322  56351
# 2  1977     4139000     333  1439    12088         14856  57938
# 3  1978     4143000     338  1476    12828         15686  58901
# 4  1979     4149000     406  1628    13745         17337  62657
# 5  1980     4192211     399  1681    16462         17182  71130
#
#    LARCENY THEFT  M/V THEFT  GRAND TOTAL  PERCENT CHANGE  VIOLENT CRIME TOTAL  \
# 1         134337      17772       234708            -3.1                26248
# 2         131516      17732       235902             0.5                28716
# 3         134012      17599       240840             2.1                30328
# 4         145278      20217       261268             8.5                33116
# 5         152089      18885       277828             6.3                35724
#
#    VIOLENT CRIME PERCENT  VIOLENT CRIME PERCENT CHANGE  PROPERTY CRIME TOTALS  \
# ...

# %%
crime_df.tail()
# Out:
#     YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  \
# 40  2015     6006401     553  1758    10150         15850  26741
# 41  2016     6016447     534  1815    10814         15828  24822
# 42  2017     6052121     569  1773    11295         17049  23735
# 43  2018     6042718     489  2106     9753         16294  18933
# 44  2019     6045674     543  1979     9261         15985  16865
#
#     LARCENY THEFT  M/V THEFT  GRAND TOTAL  PERCENT CHANGE  \
# 40         103566      13564       172182            -2.7
# 41         100876      13847       168536            -2.1
# 42          99119      13553       167093            -0.9
# 43          92414      12146       152135            -9.0
# 44          89927      11255       145815            -4.2
#
#     VIOLENT CRIME TOTAL  VIOLENT CRIME PERCENT  VIOLENT CRIME PERCENT CHANGE  \
# 40                28311                   16.4                           7.3
# ...

# %% [markdown]
# ## Trend Analysis

# %% [markdown]
# In this section we plot overall crime rate per 100,000 people over the years to see if there are any patterns or trends.

# %%
##Year vs Population

year = crime_df['YEAR']
pop = crime_df['POPULATION']

fig, ax = plt.subplots(figsize =(16, 14))
ax.barh(year, pop)

for s in ['top','right']:
    ax.spines[s].set_visible(False)

ax.invert_yaxis()

## add annotations to bar
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='black')


plt.show()

# %%
##Year vs Crime Rate per 100K people

year = crime_df['YEAR']
crime_rate = crime_df['OVERALL CRIME RATE PER 100K PEOPLE']

fig, ax = plt.subplots(figsize =(16, 14))
ax.barh(year, crime_rate)

for s in ['top','right']:
    ax.spines[s].set_visible(False)

ax.invert_yaxis()

for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='black')


plt.show()

# %%
## for every year plot the crimes in line graph.
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True

plt.plot(crime_df['YEAR'], crime_df['MURDER'], label = "Murder")
plt.plot(crime_df['YEAR'], crime_df['RAPE'], label = "Rape")
plt.plot(crime_df['YEAR'], crime_df['ROBBERY'], label = "Robbery")
plt.plot(crime_df['YEAR'], crime_df['AGG. ASSAULT'], label = "Agg. Assualt")
plt.plot(crime_df['YEAR'], crime_df['B & E'], label = "Breaking and Entering")
plt.plot(crime_df['YEAR'], crime_df['LARCENY THEFT'], label = "Larceny Theft")
plt.plot(crime_df['YEAR'], crime_df['M/V THEFT'], label = "Motor Vehicle Theft")

plt.xticks(crime_df.YEAR, rotation='vertical')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Calculate total count of crimes and rate per 100,000 people and rank them from most to least.

# %%
##creating subset of crime_df as crime_subset and rate_subset.

crime_subset = crime_df.iloc[0:45, 2:9]
crime_subset


crime_totals = crime_subset.sum(axis = 0)
crime_totals
# Out:
# MURDER             20897
# RAPE               71186
# ROBBERY           623992
# AGG. ASSAULT      901969
# B & E            1988807
# LARCENY THEFT    5953875
# M/V THEFT        1075572
# dtype: int64

# %%
crime_rank = np.argsort(-crime_totals) ##aranging the totals in descending order
crime_rank
# Out:
# MURDER           5
# RAPE             4
# ROBBERY          6
# AGG. ASSAULT     3
# B & E            2
# LARCENY THEFT    1
# M/V THEFT        0
# dtype: int64

# %% [markdown]
# Check the percentage change in crime rate per 1000K people for each crime to see if there are any notable trends.

# %%
crime_rate_subset = crime_df.iloc[0:45, 23:30]
crime_rate_subset
# Out:
#     MURDER PER 100K PEOPLE  RAPE PER 100K PEOPLE  ROBBERY PER 100K PEOPLE  \
# 1                      8.5                  32.0                    295.5
# 2                      8.0                  34.8                    292.1
# 3                      8.2                  35.6                    309.6
# 4                      9.8                  39.2                    331.3
# 5                      9.5                  40.1                    392.7
# 6                      9.9                  39.0                    424.7
# 7                     10.1                  37.4                    360.5
# 8                      8.5                  32.8                    347.4
# 9                      8.1                  37.8                    301.5
# 10                     8.0                  39.0                    302.3
# 11                     8.9                  43.6                    304.1
# 12                     9.8                  41.8                    294.7
# ...

# %%
crime_rate_changes = crime_rate_subset.pct_change()*100
crime_rate_changes
# Out:
#     MURDER PER 100K PEOPLE  RAPE PER 100K PEOPLE  ROBBERY PER 100K PEOPLE  \
# 1                      NaN                   NaN                      NaN
# 2                -5.882353              8.750000                -1.150592
# 3                 2.500000              2.298851                 5.991099
# 4                19.512195             10.112360                 7.009044
# 5                -3.061224              2.295918                18.533052
# 6                 4.210526             -2.743142                 8.148714
# 7                 2.020202             -4.102564               -15.116553
# 8               -15.841584            -12.299465                -3.633842
# 9                -4.705882             15.243902               -13.212435
# 10               -1.234568              3.174603                 0.265340
# 11               11.250000             11.794872                 0.595435
# 12               10.112360             -4.128440                -3.091088
# ...

# %%
crime_rate_changes.plot(kind = 'bar')
plt.title('Percent Change in Crime Rate per 100,000 people')
plt.xlabel('Crime')
plt.ylabel('Percentage Change')
plt.grid()
plt.show()

# %%
# crime_df['YEAR','MURDER  RATE PERCENT CHANGE PER 100K PEOPLE',
#        'RAPE RATE PERCENT CHANGE PER 100K PEOPLE',
#        'ROBBERY RATE PERCENT CHANGE PER 100K PEOPLE',
#        'AGG. ASSAULT  RATE PERCENT CHANGE PER 100K PEOPLE',
#        'B & E RATE PERCENT CHANGE PER 100K PEOPLE',
#        'LARCENY THEFT  RATE PERCENT CHANGE PER 100K PEOPLE',
#        'M/V THEFT  RATE PERCENT CHANGE PER 100K PEOPLE'].plot(kind = 'bar')
# plt.title('Percent Change in Crime Rate per 100,000 people')
# plt.xlabel('Year')
# plt.ylabel('Percentage Change')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# In this section we try to find the correlation between population and crime rates.

# %%
#plot population against crime rate per 100K people to see if there is any relationship.

correlation = crime_df['POPULATION'].corr(crime_df['OVERALL CRIME RATE PER 100K PEOPLE'])

print('Correlation between Population and Overall Crime Rate per 100K people:', correlation)
# Out:
# Correlation between Population and Overall Crime Rate per 100K people: -0.8723587460099255

# %%
plt.scatter(crime_df['POPULATION'], crime_df['OVERALL CRIME RATE PER 100K PEOPLE'])
plt.xlabel('Population')
plt.ylabel('Overall Crime Rate per 100K People')
plt.title('Correlation between Population and Crime Rate')
plt.show()

# %% [markdown]
# From the above plot we see negative correlation between Population and Overall Crime Rate.

# %%
# plot correlation between different crime rates

corr_matrix = crime_rate_subset.corr(method = 'pearson')
corr_matrix
# Out:
#                                MURDER PER 100K PEOPLE  RAPE PER 100K PEOPLE  \
# MURDER PER 100K PEOPLE                       1.000000              0.656719
# RAPE PER 100K PEOPLE                         0.656719              1.000000
# ROBBERY PER 100K PEOPLE                      0.749320              0.786032
# AGG. ASSAULT PER 100K PEOPLE                 0.676436              0.560327
# B & E PER 100K PEOPLE                        0.348565              0.679741
# LARCENY THEFT PER 100K PEOPLE                0.578486              0.708808
# M/V THEFT PER 100K PEOPLE                    0.768838              0.468561
#
#                                ROBBERY PER 100K PEOPLE  \
# MURDER PER 100K PEOPLE                        0.749320
# RAPE PER 100K PEOPLE                          0.786032
# ROBBERY PER 100K PEOPLE                       1.000000
# AGG. ASSAULT PER 100K PEOPLE                  0.772320
# B & E PER 100K PEOPLE                         0.809997
# ...

# %%
##plot the above correlation on seaborn heatmap.

import seaborn as sb
sb.heatmap(corr_matrix, cmap="YlGnBu", annot=True)

plt.show()

# %% [markdown]
# ## Predictive Analysis

# %% [markdown]
# In this section we create a Machine Learning model to predict crime rate for year 2024 with a population of 8M.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#split the dataset into traing and test sets
train_data, test_data = train_test_split(crime_df, test_size = 0.2)

# %%
# Input features and target variable
X_train = train_data[['POPULATION', 'YEAR']]
y_train = train_data['OVERALL CRIME RATE PER 100K PEOPLE']

X_test = test_data[['POPULATION', 'YEAR']]
y_test = test_data['OVERALL CRIME RATE PER 100K PEOPLE']


# machine learning algorithm
model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squeared Error: ", mse)
print("R-squared: ", r2)

#Make pedictions on the new data
new_crime_rate = pd.DataFrame({'POPULATION': [8000000], 'YEAR':[2034]})

predicted_crime_rate = model.predict(new_crime_rate) 

print("Predicted crime rate for 2024: ", predicted_crime_rate)
# Out:
# Mean Squeared Error:  91750.48110075128
# R-squared:  0.9359937793484888
# Predicted crime rate for 2024:  [5070.48977948]

# %%
crime.describe()
# Out:
#               YEAR    POPULATION      MURDER         RAPE       ROBBERY  \
# count    46.000000  4.600000e+01   46.000000    46.000000     46.000000
# mean   1997.500000  5.125707e+06  476.195652  1616.630435  14029.043478
# std      13.422618  6.708911e+05   84.214177   340.643467   3418.800472
# min    1975.000000  4.098000e+06  333.000000  1127.000000   7240.000000
# 25%    1986.250000  4.481000e+06  400.750000  1318.750000  12027.250000
# 50%    1997.500000  5.114500e+06  490.500000  1636.000000  13628.500000
# 75%    2008.750000  5.683008e+06  550.750000  1872.000000  15358.500000
# max    2020.000000  6.055578e+06  632.000000  2280.000000  21580.000000
#
#        AGG. ASSAULT         B & E  LARCENY THEFT     M/V THEFT    GRAND TOTAL  \
# count     46.000000     46.000000      46.000000     46.000000      46.000000
# mean   20227.826087  44818.913043  133929.152174  24074.934783  239172.695652
# std     4052.913664  13698.069985   23174.984288   8770.183070   46711.392754
# ...
